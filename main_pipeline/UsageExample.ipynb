# %% [markdown]
# <a href="https://colab.research.google.com/github/freida20git/bird-detection-tracking/blob/main/main_pipeline/UsageExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
 Make sure to install required : https://github.com/freida20git/bird-detection-tracking/tree/main/requirements.txt
 and import or clone the following files:
  OcSort_counter.py
  VideoDrawings.py,
  sort_counter.py
  bestbirdsonly.pt
  sort.py
'''

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# %%
# download input .mp4 video for example: Birds_Sky.mp4

# %%
def video(save_path):
  compressed_path = "/content/result_compressed.mp4"

  os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

  # Show video
  mp4 = open(compressed_path,'rb').read()
  return "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# # **usage example for SORT tracking:**

# %%
# usage example for SORT tracking:
import sort_counter # sort_counter.py file
from sort_counter import main_sort
main_sort('/content/Birds_Sky.mp4', sort_output_path, '/content/bestbirdsonly.pt')
# Out:
# Total number of birds detected: 7

# %% [markdown]
# # **usage example for OcSORT tracking:**

# %% [markdown]
# **Dont forget to install and clone OCsort file:**

# %%
'''
Dont forget to install and clone OCsort file:

os.chdir('/content')
# !git clone https://github.com/noahcao/OC_SORT.git
# !cd OC_SORT
# !pip3 install -r /content/OC_SORT/requirements.txt
# !python3 setup.py develop

 you can double check if loaded succesfully using this following code:
import sys
sys.path.append('/content/OC_SORT') # Add the parent directory to sys.path
from trackers.ocsort_tracker.ocsort import OCSort
tracker = OCSort(det_thresh=0.5)
print("OCSort loaded successfully!")

'''

# same for ocsort:
import  OcSort_counter #from OcSort_counter.py file
from sort_counter import main_ocsort
def main_ocsort('/content/Birds_Sky.mp4', sort_output_path, '/content/bestbirdsonly.pt')

# %% [markdown]
# # Output:

# %%
# !rm "/content/result_compressed.mp4"
data_url=video(sort_output_path)
HTML("""
  <video width=400 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url)
# Out:
#   <video width=400 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>
